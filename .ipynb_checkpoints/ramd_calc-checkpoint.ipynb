# %%
import pandas as pd
from scipy.io import savemat
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from helpers_ramd import *

# %% [markdown]
# <p style="color: brown; font-size: 24px;"><strong><em>1) Data loading</em></strong></p>

# %%
# Pandas - openpyxl 
# Pandas - openpyxl 
data = load_excel(r'C:\Users\anast\Desktop\Ramd_calc\Data_xlsx\results pbcatom.xlsx')
data2 = load_excel(r'C:\Users\anast\Desktop\Ramd_calc\Data_xlsx\results pbcatom ADDITIONAL.xlsx')

# %%
forces_data = {
    'force250': data[:, [0, 1]],
    'force275': data[:, [3, 4]],
    'force300': data[:, [6, 7]],
    'force325': data[:, [9, 10]],
    'force350': data[:, [12, 13]],
    'force375': data[:, [15, 16]],
    'force400': data[:, [18, 19]],
    'force425': data[:, [21, 22]],
    'force450': data[:, [24, 25]],
    'force475': data[:, [27, 28]],
    'force500': data[:, [30, 31]],
    'force525': data[:, [33, 34]],
    'force550': data[:, [36, 37]],
    'force575': data[:, [39, 40]],
    # 'force600': data[:, [42, 43]],
    # 'force588': data[:, [3, 40]],
    # 'force575': data[:, [6, 7]],
    # 'force563': data[:, [9, 10]],
    # 'force538': data[:, [15, 16]],
    # 'force513': data[:, [21, 22]],
    # 'force488': data[:, [27, 28]],
    # 'force475': data[:, [30, 31]],
    # 'force463': data[:, [33, 34]],
    # 'force425': data[:, [39, 40]],
    # 'force375': data[:, [45, 46]],
    # 'force350': data[:, [48, 49]],
    # 'force325': data[:, [51, 52]],
    # 'force300': data[:, [54, 55]],
    # 'force275': data[:, [57, 58]],
    # 'force250': data[:, [60, 61]]
 # второй набор: results pbcatom ADDITIONAL.xlsx :  
    'force488': data2[:, [0, 1]],
    'force513': data2[:, [3, 4]],
    'force538': data2[:, [6, 7]],
    'force563': data2[:, [9, 10]],
    'force588': data2[:, [12, 13]],
    'force263': data2[:, [15, 16]],
    'force288': data2[:, [18, 19]],
    'force313': data2[:, [21, 22]],
    'force338': data2[:, [24, 25]],
    'force363': data2[:, [27, 28]],
    'force388': data2[:, [30, 31]],
    'force413': data2[:, [33, 34]],
    'force438': data2[:, [36, 37]],
    'force463': data2[:, [39, 40]]
}

# Преобразуем данные в массивы NumPy с типом float
for key in forces_data:
    forces_data[key] = np.array(forces_data[key], dtype=float)

# Сохранение в файл .mat
savemat(r'C:\Users\anast\Desktop\RAMD\matscripts\forces_with_pbcatom.mat', forces_data)

# %%
# # Сheck (пример для force250)
# if 'force250' in data:
#     print("\nПервые 10 строк force250:")
#     print(forces_data['force250'][:10, :])

# %% [markdown]
# <p style="color: brown; font-size: 24px;"><strong><em>2) Procedure of approximation and its interpretation</em></strong><br><span style="font-size: 18px; font-style: italic;">Data loading and initial processing</span></p>

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 250 : </em></strong></p>

# %%
force = forces_data['force250']
force_value = 250

# Фильтрация
valid_ind = (~np.isnan(force[:, 1])) & (force[:, 1] > 0)  
t = force[valid_ind, 0]
N = force[valid_ind, 1]

# # Вывод данных для проверки
# print("Время (t):", t)
# print("Величины сил (N):", N)

# %% [markdown]
# <span style="color:darkblue;font-size: 18px;"><em>а) Поиск классической экпоненциальной релаксации:</em></span>

# %%
# создаем пустые массивы, которые будут заполняться значениями
tau_all = [] #список всех времен диссоциации
forces_all = [] # список сил
pend_var = [] # для коэффициентов линейной аппроксимации
tau_var = [] # для хранения значений времени диссоциации
lambda_var = [] # значения скорости диссоциации

# %% [markdown]
# Время диссоциации (tau) — это среднее время, которое требуется для того, чтобы лиганд отсоединился от белка

# %%
tau_frac = 15500
N_cut_max = 13

# %%
N0 = N[0] #берет начальное значение количества связанных лигандов
# n = np.log(N0 / N) #логарифм отношения начального количества лигандов к текущему количеству
n = np.log(N / N0)

# %%
for N_cut in range(N_cut_max):
    t_fit = []
    n_fit = []
    
    # Фильтрация данных: отбираем значения, которые больше N_cut и tau_frac
    for i in range(len(t)):
        if N[i] > N_cut and t[i] > tau_frac:
            t_fit.append(t[i])
            n_fit.append(n[i])
            
    t_fit = [value for value in t_fit if value > 0] # Фильтрация положительных значений для t_fit
    pend = np.polyfit(t_fit, n_fit, 1)
    tau = (1 / abs(pend[0])) / 1e4  # Делим на 10^4 для масштабирования
    lambda_ = pend[0] * 1e4  # Умножаем на 10^4 для масштабирования

    tau_var.append(round(tau, 15)) 
    lambda_var.append(round(lambda_, 15)) 
    pend_var.append(pend)

# Вывод для проверки
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
# Out:
# tau_var: [2.327723210471358, 2.918085047998354, 3.726005080365139, 3.860288824372526, 3.895274370738051, 3.455521269163856, 1.486313322924282, 1.532312945503681, 1.514070033696745, 1.343795448412747, 1.448921520062662, 1.537635853521032, 1.741051527587008]
# lambda_var: [-0.429604342776434, -0.342690491727082, -0.268383960416394, -0.259047974256834, -0.256721325591893, -0.289391938901876, -0.672805649102658, -0.652608204436525, -0.660471429817817, -0.744160877446915, -0.690168505438964, -0.650349039215039, -0.574365539534571]

# %%
plt.plot(range(13), tau_var[:13], label='tau (ps)')
plt.xlabel('N_cut')
plt.ylabel('tau (ps)')
plt.grid(True)
plt.legend()
plt.show()

# %%
N_cut = 6

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %% [markdown]
# <span style="color:darkblue;font-size: 18px;"><em>б) Начальная неклассическая (дробная) релаксация:</em></span>

# %%
# Определение t0 и tend (в зависимости от данных)
t0 = 21  # т.к. Python считает с нуля, нужно уменьшить индекс на 1
tend = 63

# %%
print(tau)
# Out:
# 1.741051527587008

# %%
np.set_printoptions(precision=15, suppress=False)
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.9563890424232262, pinit: [  1.956389042423226 -19.415390500747822]
# t[t0:tend]: [ 5250.  5500.  5750.  6000.  6250.  6500.  6750.  7000.  7250.  7500.
#   7750.  8000.  8250.  8500.  8750.  9000.  9250.  9500.  9750. 10000.
#  10250. 10500. 10750. 11000. 11250. 11500. 11750. 12000. 12250. 12500.
#  12750. 13000. 13250. 13500. 13750. 14000. 14250. 14500. 14750. 15000.
#  15250. 15500.]
# n[t0:tend]: [-0.040821994520255 -0.040821994520255 -0.040821994520255
#  -0.083381608939051 -0.083381608939051 -0.174353387144778
#  -0.174353387144778 -0.174353387144778 -0.174353387144778
#  -0.174353387144778 -0.174353387144778 -0.174353387144778
#  -0.174353387144778 -0.22314355131421  -0.22314355131421
#  -0.22314355131421  -0.22314355131421  -0.22314355131421
#  -0.22314355131421  -0.328504066972036 -0.328504066972036
#  -0.328504066972036 -0.328504066972036 -0.328504066972036
#  -0.328504066972036 -0.328504066972036 -0.328504066972036
# ...

# %%
tau = tau_var[N_cut] #+1 убрала. индексация разная
lambda_ = lambda_var[N_cut] * 1e-4 #масштабирование
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 1.486313322924282, lambda: -6.72805649102658e-05

# %%
print("pend (Python):", pend_var)
# Out:
# pend (Python): [array([-4.296043427764345e-05,  1.909099757571174e-01]), array([-3.426904917270815e-05, -1.034464391638061e-01]), array([-2.683839604163939e-05, -3.342516095629092e-01]), array([-2.590479742568345e-05, -3.621718392258802e-01]), array([-2.567213255918932e-05, -3.688245278365091e-01]), array([-2.893919389018761e-05, -2.786222157418009e-01]), array([-6.728056491026582e-05,  6.274386325522530e-01]), array([-6.526082044365251e-05,  5.878995252496142e-01]), array([-6.604714298178171e-05,  6.031290563343013e-01]), array([-7.441608774469148e-05,  7.634440606464762e-01]), array([-6.901685054389643e-05,  6.678784428235935e-01]), array([-6.503490392150393e-05,  5.983866199414489e-01]), array([-5.743655395345706e-05,  4.692778863206207e-01])]

# %%
t_fit = []
n_fit = []
for i in range(len(t)):
    if N[i] > N_cut and t[i] > tau_frac:
        t_fit.append(t[i])
        n_fit.append(n[i])

# %%
plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut + 1], pinit)

# %%
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut + 1], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %%
# two_in_one(
#     float(force_value), 
#     t, 
#     t_fit, 
#     n, 
#     N, 
#     float(N0), 
#     float(tau_frac), 
#     np.array(pend_var[N_cut + 1][:2]),  
#     np.array(pinit), 
#     xlim1=[0, 2.4 * 10**5], 
#     ylim1=[-3.3, 0], 
#     xlim2=[0, 2.4 * 10**5], 
#     axs=[0.6, 0.6, 0.35, 0.35],  
#     output_file='output_two_in_one_styled_v2.png'
# )

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 263 :</em></strong></p>

# %%
force_value = 263 
force = forces_data['force263'] 
force = force.astype(float)
valid_ind = (~np.isnan(force[:, 1])) & (force[:, 1] > 0)
t = force[valid_ind, 0]
N = force[valid_ind, 1]

# %%
#  а) Поиск классической экпоненциальной релаксации:
# Время термализации
tau_frac = 18000 

tau_all = []  
forces_all = []

N0 = N[0]
n = np.log(N / N0) 

N_cut_max = 11 
N_cut = 4   

# Поиск места обрезания
pend_var = []
tau_var = []
lambda_var = []

for current_cut in range(N_cut_max):  # Цикл по количеству обрезок
    t_fit, n_fit = filter_data(t, N, n, current_cut, tau_frac)
    pend = np.polyfit(t_fit, n_fit, 1)
    pend_var.append(pend) 
    tau = 1 / abs(pend[0])
    lambda_ = pend[0]
    tau_var.append(tau)
    lambda_var.append(lambda_)

# Используем tau и lambda для N_cut
tau_final = tau_var[N_cut]
lambda_final = lambda_var[N_cut]

# для заданного N_cut
print(f"tau: {tau_final}, lambda: {lambda_final}")

# Построение графика tau в зависимости от количества N_cut
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)
# Out:
# tau: 40351.13289354248, lambda: -2.4782451651067102e-05

# %%
# Определение t0 и tend (можно адаптировать в зависимости от данных)
t0 = 20  
tend = 91 
# tend = 131;
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
# N_cut = 
tau = tau_var[N_cut + 1]
lambda_ = lambda_var[N_cut + 1]
print(f"tau: {tau}, lambda: {lambda_}")
t_fit, n_fit = filter_data(t, N, n, N_cut, tau_frac)
# Out:
# p: 1.2979681991476664, pinit: [  1.2979682  -13.37121077]
# tau: 40953.806767133196, lambda: -2.441775451268998e-05

# %%
plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut + 1], pinit)

# %%
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut + 1], pinit)
