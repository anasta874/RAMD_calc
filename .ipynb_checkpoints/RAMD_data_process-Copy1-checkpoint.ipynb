# %%
import pandas as pd
from scipy.io import savemat
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from data_func import *

# %% [markdown]
# <p style="color: brown; font-size: 24px;"><strong><em>1) Data loading</em></strong></p>

# %%
# Pandas - openpyxl 
data = load_excel(r'C:\Users\anast\Desktop\Ramd_calc\Data_xlsx\results pbcatom.xlsx')
data2 = load_excel(r'C:\Users\anast\Desktop\Ramd_calc\Data_xlsx\results pbcatom ADDITIONAL.xlsx')

# %%
forces_data = {
    'force250': data[:, [0, 1]],
    'force275': data[:, [3, 4]],
    'force300': data[:, [6, 7]],
    'force325': data[:, [9, 10]],
    'force350': data[:, [12, 13]],
    'force375': data[:, [15, 16]],
    'force400': data[:, [18, 19]],
    'force425': data[:, [21, 22]],
    'force450': data[:, [24, 25]],
    'force475': data[:, [27, 28]],
    'force500': data[:, [30, 31]],
    'force525': data[:, [33, 34]],
    'force550': data[:, [36, 37]],
    'force575': data[:, [39, 40]],
    # 'force600': data[:, [42, 43]],
    # 'force588': data[:, [3, 40]],
    # 'force575': data[:, [6, 7]],
    # 'force563': data[:, [9, 10]],
    # 'force538': data[:, [15, 16]],
    # 'force513': data[:, [21, 22]],
    # 'force488': data[:, [27, 28]],
    # 'force475': data[:, [30, 31]],
    # 'force463': data[:, [33, 34]],
    # 'force425': data[:, [39, 40]],
    # 'force375': data[:, [45, 46]],
    # 'force350': data[:, [48, 49]],
    # 'force325': data[:, [51, 52]],
    # 'force300': data[:, [54, 55]],
    # 'force275': data[:, [57, 58]],
    # 'force250': data[:, [60, 61]]
 # второй набор: results pbcatom ADDITIONAL.xlsx :  
    'force488': data2[:, [0, 1]],
    'force513': data2[:, [3, 4]],
    'force538': data2[:, [6, 7]],
    'force563': data2[:, [9, 10]],
    'force588': data2[:, [12, 13]],
    'force263': data2[:, [15, 16]],
    'force288': data2[:, [18, 19]],
    'force313': data2[:, [21, 22]],
    'force338': data2[:, [24, 25]],
    'force363': data2[:, [27, 28]],
    'force388': data2[:, [30, 31]],
    'force413': data2[:, [33, 34]],
    'force438': data2[:, [36, 37]],
    'force463': data2[:, [39, 40]]
}

for key in forces_data:
    forces_data[key] = np.array(forces_data[key], dtype=float)
    
savemat(r'C:\Users\anast\Desktop\RAMD\matscripts\forces_with_pbcatom.mat', forces_data)

# %%
# Create empty arrays to store values
tau_all = []       # List of all dissociation times
forces_all = []    # List of forces

# %% [markdown]
# <p style="color: brown; font-size: 24px;"><strong><em>2) Procedure of approximation and its interpretation</em></strong><br><span style="font-size: 18px; font-style: italic;">Data loading and initial processing</span></p>

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 250 : </em></strong></p>

# %%
force = forces_data['force250']
force_value = 250
t, N = filter_data(force)
pend_var = []
tau_var = []
lambda_var = []
N0 = N[0]
ln_N = np.log(N)
plot_ln_N_vs_t(t, N)

# %% [markdown]
# <span style="color:darkblue;font-size: 18px;"><em>a) Finding classical exponential relaxation:</em></span>

# %%
t0 = 21  # since Python indexes from zero, we need to subtract 1
tend = 63
tau_frac = 15500 
N_cut_max = 13

# %%
n = np.log(N / N0)
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)

x_values = list(range(len(tau_var)))
y_values = tau_var
plot_tau(x_values, y_values, force_value)
# Out:
# tau_var: [2.327723210471358, 2.918085047998354, 3.726005080365139, 3.860288824372526, 3.895274370738051, 3.455521269163856, 1.486313322924282, 1.532312945503681, 1.514070033696745, 1.343795448412747, 1.448921520062662, 1.537635853521032, 1.741051527587008]
# lambda_var: [-0.429604342776434, -0.342690491727082, -0.268383960416394, -0.259047974256834, -0.256721325591893, -0.289391938901876, -0.672805649102658, -0.652608204436525, -0.660471429817817, -0.744160877446915, -0.690168505438964, -0.650349039215039, -0.574365539534571]
# pend_var: [array([-4.29604343e-05,  1.90909976e-01]), array([-3.42690492e-05, -1.03446439e-01]), array([-2.6838396e-05, -3.3425161e-01]), array([-2.59047974e-05, -3.62171839e-01]), array([-2.56721326e-05, -3.68824528e-01]), array([-2.89391939e-05, -2.78622216e-01]), array([-6.72805649e-05,  6.27438633e-01]), array([-6.52608204e-05,  5.87899525e-01]), array([-6.60471430e-05,  6.03129056e-01]), array([-7.44160877e-05,  7.63444061e-01]), array([-6.90168505e-05,  6.67878443e-01]), array([-6.50349039e-05,  5.98386620e-01]), array([-5.74365540e-05,  4.69277886e-01])]

# %%
N_cut = 6

a = list(range(len(tau_var)))
plot_tau_with_cutoff(a, tau_var, N_cut, force_value)

# %% [markdown]
# <span style="color:darkblue;font-size: 18px;"><em>b) Initial non-classical (fractional) relaxation</em></span>

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.9563890424232262, pinit: [  1.95638904 -19.4153905 ]
# t[t0:tend]: [ 5250.  5500.  5750.  6000.  6250.  6500.  6750.  7000.  7250.  7500.
#   7750.  8000.  8250.  8500.  8750.  9000.  9250.  9500.  9750. 10000.
#  10250. 10500. 10750. 11000. 11250. 11500. 11750. 12000. 12250. 12500.
#  12750. 13000. 13250. 13500. 13750. 14000. 14250. 14500. 14750. 15000.
#  15250. 15500.]
# n[t0:tend]: [-0.04082199 -0.04082199 -0.04082199 -0.08338161 -0.08338161 -0.17435339
#  -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.17435339
#  -0.17435339 -0.22314355 -0.22314355 -0.22314355 -0.22314355 -0.22314355
#  -0.22314355 -0.32850407 -0.32850407 -0.32850407 -0.32850407 -0.32850407
#  -0.32850407 -0.32850407 -0.32850407 -0.32850407 -0.38566248 -0.38566248
#  -0.38566248 -0.38566248 -0.4462871  -0.4462871  -0.4462871  -0.4462871
#  -0.4462871  -0.4462871  -0.4462871  -0.4462871  -0.4462871  -0.4462871 ]

# %%
# Values of tau and lambda for N_cut = 6
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 1.486313322924282, lambda: -6.72805649102658e-05

# %%
# Filtering data based on both conditions
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

# Calling functions with filtered data
plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)
# красная пунктирная линия - порог tau_frac, который разделяет начальную (дробную) фазу релаксации от классической экспоненциальной релаксации
# черная пунктирно-точечная линия - время диссоциации tau, которое связано со скоростью диссоциации, полученной из аппроксимации

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 263 :</em></strong></p>

# %%
force = forces_data['force263']
force_value = 263
t, N = filter_data(force)
pend_var = []
tau_var = []
lambda_var = []
N0 = N[0]
ln_N = np.log(N)
plot_ln_N_vs_t(t, N)

# %%
t0 = 19  # since Python indexes from zero, we need to subtract 1
tend = 91
tau_frac = 18000
N_cut_max = 11

# %%
n = np.log(N / N0)
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)

x_values = list(range(len(tau_var)))
y_values = tau_var
plot_tau(x_values, y_values, force_value)
# Out:
# tau_var: [1.994138309379543, 2.212693655121674, 2.59893485240299, 3.358359213378619, 4.035113289354248, 4.09538067671332, 4.165570785525791, 4.280928421707773, 4.213316412088724, 3.46369752597636, 2.943173559434476]
# lambda_var: [-0.501469730206999, -0.451937844032463, -0.384773015404905, -0.297764454742162, -0.247824516510671, -0.2441775451269, -0.240063139360091, -0.233594188337556, -0.237342725348334, -0.288708812620154, -0.339769293181659]
# pend_var: [array([-5.01469730e-05,  7.00241327e-01]), array([-4.51937844e-05,  5.23381906e-01]), array([-3.84773015e-05,  3.04995261e-01]), array([-2.97764455e-05,  3.94714634e-02]), array([-2.47824517e-05, -1.07012473e-01]), array([-2.44177545e-05, -1.17558298e-01]), array([-2.40063139e-05, -1.29384650e-01]), array([-2.33594188e-05, -1.46543267e-01]), array([-2.37342725e-05, -1.36506733e-01]), array([-2.88708813e-05, -7.88415874e-03]), array([-3.39769293e-05,  1.13841393e-01])]

# %%
N_cut = 4

a = list(range(len(tau_var)))
plot_tau_with_cutoff(a, tau_var, N_cut, force_value)

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.3501246328322074, pinit: [  1.35012463 -13.86462908]
# t[t0:tend]: [ 4750.  5000.  5250.  5500.  5750.  6000.  6250.  6500.  6750.  7000.
#   7250.  7500.  7750.  8000.  8250.  8500.  8750.  9000.  9250.  9500.
#   9750. 10000. 10250. 10500. 10750. 11000. 11250. 11500. 11750. 12000.
#  12250. 12500. 12750. 13000. 13250. 13500. 13750. 14000. 14250. 14500.
#  14750. 15000. 15250. 15500. 15750. 16000. 16250. 16500. 16750. 17000.
#  17250. 17500. 17750. 18000. 18250. 18500. 18750. 19000. 19250. 19500.
#  19750. 20000. 20250. 20500. 20750. 21000. 21250. 21500. 21750. 22000.
#  22250. 22500.]
# n[t0:tend]: [-0.08338161 -0.08338161 -0.08338161 -0.08338161 -0.08338161 -0.12783337
#  -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.17435339
#  -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.17435339
#  -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.17435339 -0.27443685
#  -0.27443685 -0.27443685 -0.32850407 -0.38566248 -0.38566248 -0.38566248
#  -0.38566248 -0.38566248 -0.38566248 -0.38566248 -0.38566248 -0.38566248
#  -0.38566248 -0.38566248 -0.38566248 -0.38566248 -0.38566248 -0.38566248
#  -0.38566248 -0.4462871  -0.51082562 -0.51082562 -0.51082562 -0.51082562
#  -0.51082562 -0.5798185  -0.5798185  -0.5798185  -0.5798185  -0.5798185
#  -0.5798185  -0.5798185  -0.5798185  -0.5798185  -0.5798185  -0.5798185
#  -0.5798185  -0.5798185  -0.5798185  -0.5798185  -0.5798185  -0.5798185
#  -0.5798185  -0.5798185  -0.5798185  -0.5798185  -0.5798185  -0.5798185 ]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 4.035113289354248, lambda: -2.4782451651067102e-05

# %%
# Filtering data based on both conditions
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

# Calling functions with filtered data
plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 275 :</em></strong></p>

# %%
force = forces_data['force275']
force_value = 275
t, N = filter_data(force)
pend_var = []
tau_var = []
lambda_var = []
N0 = N[0]
ln_N = np.log(N)

plot_ln_N_vs_t(t, N)

# %%
tau_frac = 0
N_cut_max = 41
t0 = 19  # since Python indexes from zero, we need to subtract 1
tend = 91

# %%
n = np.log(N / N0)
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)

x_values = list(range(len(tau_var)))
y_values = tau_var
plot_tau(x_values, y_values, force_value)
# Out:
# tau_var: [2.820193872615776, 2.820193872615776, 2.60916825561046, 2.34465124005152, 2.35579982901304, 2.452093659800037, 2.503852777104049, 2.53369038559786, 2.643564323810544, 2.643564323810544, 2.654484058923776, 2.694396869313098, 2.699161678781022, 2.699161678781022, 2.63437461806452, 2.623402657637698, 2.673671462179489, 2.683463858632426, 2.729628483900744, 2.75455957189726, 2.759958031975607, 2.759958031975607, 2.699306648519719, 2.636593534215924, 2.643006935100388, 2.645950802221278, 2.705445654431666, 2.928021728583455, 2.928021728583455, 3.180088196148662, 3.180088196148662, 3.357909311152262, 3.357909311152262, 3.396905385350628, 3.406592952164518, 3.374100988602488, 3.299179781547709, 3.137281501497176, 3.12610436597029, 3.196267642985958, 3.351007218991475]
# lambda_var: [-0.354585551621131, -0.354585551621131, -0.38326389946287, -0.426502663985978, -0.424484282443874, -0.40781476515116, -0.399384504210586, -0.394681215070418, -0.378277158226496, -0.378277158226496, -0.376721041755073, -0.3711405737548, -0.370485402138494, -0.370485402138494, -0.379596733563544, -0.381184335957208, -0.374017531377933, -0.372652680520777, -0.366350221613661, -0.363034443038467, -0.362324350013464, -0.362324350013464, -0.370465504743002, -0.379277270850693, -0.378356933808809, -0.377935976421216, -0.36962487062416, -0.341527520181276, -0.341527520181276, -0.314456687462656, -0.314456687462656, -0.297804350069494, -0.297804350069494, -0.294385591165584, -0.293548426255215, -0.296375242880382, -0.303105640254282, -0.318747297468454, -0.31988695287517, -0.312864913610863, -0.29841773969707]
# pend_var: [array([-3.54585552e-05, -1.22796500e-01]), array([-3.54585552e-05, -1.22796500e-01]), array([-3.83263899e-05, -3.22930755e-02]), array([-4.26502664e-05,  9.41680783e-02]), array([-4.24484282e-05,  9.02265944e-02]), array([-4.07814765e-05,  6.10441456e-02]), array([-3.99384504e-05,  4.70258150e-02]), array([-3.94681215e-05,  3.94843686e-02]), array([-3.78277158e-05,  1.51611386e-02]), array([-3.78277158e-05,  1.51611386e-02]), array([-3.76721042e-05,  1.29681538e-02]), array([-3.71140574e-05,  5.74319067e-03]), array([-3.70485402e-05,  4.91330662e-03]), array([-3.70485402e-05,  4.91330662e-03]), array([-3.79596734e-05,  1.60239725e-02]), array([-3.81184336e-05,  1.81298341e-02]), array([-3.74017531e-05,  1.11319613e-02]), array([-3.72652681e-05,  9.83990249e-03]), array([-3.66350222e-05,  4.20779702e-03]), array([-3.63034443e-05,  1.36095667e-03]), array([-3.6232435e-05,  7.6447853e-04]), array([-3.6232435e-05,  7.6447853e-04]), array([-3.70465505e-05,  7.36001293e-03]), array([-3.79277271e-05,  1.40636781e-02]), array([-3.78356934e-05,  1.34769249e-02]), array([-3.77935976e-05,  1.32176533e-02]), array([-3.69624871e-05,  8.53932675e-03]), array([-3.4152752e-05, -6.0856942e-03]), array([-3.4152752e-05, -6.0856942e-03]), array([-3.14456687e-05, -1.89935920e-02]), array([-3.14456687e-05, -1.89935920e-02]), array([-2.97804350e-05, -2.64092482e-02]), array([-2.97804350e-05, -2.64092482e-02]), array([-2.94385591e-05, -2.78679187e-02]), array([-2.93548426e-05, -2.82139469e-02]), array([-2.96375243e-05, -2.70890191e-02]), array([-3.03105640e-05, -2.46086292e-02]), array([-3.18747297e-05, -1.93306502e-02]), array([-3.19886953e-05, -1.88795216e-02]), array([-3.12864914e-05, -2.05593936e-02]), array([-2.98417740e-05, -2.36638441e-02])]

# %%
N_cut = 8

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.0791023874106562, pinit: [  1.07910239 -11.00260765]
# t[t0:tend]: [ 7600.  8000.  8400.  8800.  9200.  9600. 10000. 10400. 10800. 11200.
#  11600. 12000. 12400. 12800. 13200. 13600. 14000. 14400. 14800. 15200.
#  15600. 16000. 16400. 16800. 17200. 17600. 18000. 18400. 18800. 19200.
#  19600. 20000. 20400. 20800. 21200. 21600. 22000. 22400. 22800. 23200.
#  23600. 24000. 24400. 24800. 25200. 25600. 26000. 26400. 26800. 27200.
#  27600. 28000. 28400. 28800. 29200. 29600. 30000. 30400. 30800. 31200.
#  31600. 32000. 32400. 32800. 33200. 33600. 34000. 34400. 34800. 35200.
#  35600. 36000.]
# n[t0:tend]: [-0.27443685 -0.27443685 -0.27443685 -0.30110509 -0.30110509 -0.30110509
#  -0.30110509 -0.32850407 -0.32850407 -0.35667494 -0.35667494 -0.38566248
#  -0.41551544 -0.4780358  -0.4780358  -0.54472718 -0.54472718 -0.54472718
#  -0.61618614 -0.61618614 -0.61618614 -0.61618614 -0.65392647 -0.65392647
#  -0.65392647 -0.65392647 -0.65392647 -0.69314718 -0.69314718 -0.73396918
#  -0.73396918 -0.73396918 -0.77652879 -0.77652879 -0.77652879 -0.77652879
#  -0.77652879 -0.77652879 -0.77652879 -0.82098055 -0.82098055 -0.82098055
#  -0.82098055 -0.91629073 -0.96758403 -0.96758403 -1.02165125 -1.02165125
#  -1.02165125 -1.02165125 -1.02165125 -1.07880966 -1.13943428 -1.13943428
#  -1.13943428 -1.13943428 -1.13943428 -1.2039728  -1.2039728  -1.2039728
#  -1.2039728  -1.2039728  -1.2039728  -1.2039728  -1.2039728  -1.2039728
#  -1.2039728  -1.27296568 -1.27296568 -1.27296568 -1.27296568 -1.27296568]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 2.643564323810544, lambda: -3.78277158226496e-05

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %%
force = forces_data['force288']
force_value = 288

# %%
# Filtering
t, N = filter_data(force)

# %%
tau_frac = 18000
N_cut_max = 26

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [1.756793995758591, 1.850319448972752, 1.95173971160311, 1.963033603648919, 1.91280309490238, 1.791155790721697, 1.704919430218384, 1.7023151629496, 1.614683127181714, 1.63343107651306, 1.697229429699648, 1.736878129480916, 1.969650506957637, 1.969650506957637, 1.992448502863642, 2.01499022219176, 2.022761154506354, 2.088780829971631, 2.127753492362936, 2.138836373353004, 2.138836373353004, 1.849622442575647, 1.921028779476072, 1.936853607873762, 1.889448832138447, 1.788366767435638]
# lambda_var: [-0.56921870316855, -0.540447218751969, -0.512363402791362, -0.509415630043818, -0.522792964244464, -0.558298728217872, -0.586537980784177, -0.587435289166608, -0.619316560113817, -0.612208261725211, -0.589195533910207, -0.575745634092854, -0.507704283814605, -0.507704283814605, -0.50189502943878, -0.496280323838134, -0.494373741443559, -0.47874817005745, -0.469979254452765, -0.467543947007187, -0.467543947007187, -0.540650879326201, -0.520554408493939, -0.516301281591322, -0.529254872103743, -0.559169415473937]
# pend_var: [array([-5.69218703e-05,  4.37367249e-01]), array([-5.40447219e-05,  3.31412402e-01]), array([-5.12363403e-05,  2.39018353e-01]), array([-5.09415630e-05,  2.29399043e-01]), array([-5.22792964e-05,  2.72175069e-01]), array([-5.58298728e-05,  3.80364897e-01]), array([-5.86537981e-05,  4.62444551e-01]), array([-5.87435289e-05,  4.64882239e-01]), array([-6.19316560e-05,  5.49910897e-01]), array([-6.12208262e-05,  5.33900900e-01]), array([-5.89195534e-05,  4.78182043e-01]), array([-5.75745634e-05,  4.46032884e-01]), array([-5.07704284e-05,  2.87466776e-01]), array([-5.07704284e-05,  2.87466776e-01]), array([-5.01895029e-05,  2.74105491e-01]), array([-4.96280324e-05,  2.61266925e-01]), array([-4.94373741e-05,  2.56963194e-01]), array([-4.78748170e-05,  2.22774093e-01]), array([-4.69979254e-05,  2.03673785e-01]), array([-4.67543947e-05,  1.98414805e-01]), array([-4.67543947e-05,  1.98414805e-01]), array([-5.40650879e-05,  3.53993103e-01]), array([-5.20554408e-05,  3.13276286e-01]), array([-5.16301282e-05,  3.04699147e-01]), array([-5.29254872e-05,  3.30678001e-01]), array([-5.59169415e-05,  3.91483309e-01])]

# %%
N_cut = 4

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 19  # since Python indexes from zero, we need to subtract 1
tend = 91

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.1284001694120462, pinit: [  1.12840017 -11.55969396]
# t[t0:tend]: [ 4750.  5000.  5250.  5500.  5750.  6000.  6250.  6500.  6750.  7000.
#   7250.  7500.  7750.  8000.  8250.  8500.  8750.  9000.  9250.  9500.
#   9750. 10000. 10250. 10500. 10750. 11000. 11250. 11500. 11750. 12000.
#  12250. 12500. 12750. 13000. 13250. 13500. 13750. 14000. 14250. 14500.
#  14750. 15000. 15250. 15500. 15750. 16000. 16250. 16500. 16750. 17000.
#  17250. 17500. 17750. 18000. 18250. 18500. 18750. 19000. 19250. 19500.
#  19750. 20000. 20250. 20500. 20750. 21000. 21250. 21500. 21750. 22000.
#  22250. 22500.]
# n[t0:tend]: [-0.14310084 -0.16251893 -0.18232156 -0.18232156 -0.18232156 -0.18232156
#  -0.18232156 -0.18232156 -0.20252426 -0.22314355 -0.24419696 -0.24419696
#  -0.24419696 -0.24419696 -0.24419696 -0.24419696 -0.26570317 -0.28768207
#  -0.28768207 -0.28768207 -0.28768207 -0.28768207 -0.28768207 -0.28768207
#  -0.28768207 -0.28768207 -0.28768207 -0.28768207 -0.31015493 -0.35667494
#  -0.35667494 -0.3807725  -0.43078292 -0.43078292 -0.4567584  -0.4567584
#  -0.4567584  -0.4567584  -0.4567584  -0.4567584  -0.4567584  -0.4567584
#  -0.4567584  -0.48342665 -0.48342665 -0.48342665 -0.48342665 -0.48342665
#  -0.51082562 -0.5389965  -0.5389965  -0.597837   -0.597837   -0.62860866
#  -0.66035736 -0.66035736 -0.66035736 -0.66035736 -0.66035736 -0.66035736
#  -0.66035736 -0.76214005 -0.76214005 -0.76214005 -0.76214005 -0.7985077
#  -0.7985077  -0.7985077  -0.83624802 -0.87546874 -0.87546874 -0.87546874]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 1.91280309490238, lambda: -5.22792964244464e-05

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 300 :</em></strong></p>

# %%
force = forces_data['force300']
force_value = 300
t, N = filter_data(force)

# %%
tau_frac = 0
N_cut_max = 57 #почему в матлабе значение выше?????

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("Количество значений в tau_var:", len(tau_var))
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# Количество значений в tau_var: 57
# tau_var: [1.187110632517147, 1.281750004662752, 1.328490318573773, 1.375012751882394, 1.400900545384442, 1.410778211230106, 1.416071777504562, 1.444679009037506, 1.46132159010269, 1.46132159010269, 1.454436962642793, 1.440683413240546, 1.3427052143981, 1.301073268260061, 1.297535101220069, 1.267910738771077, 1.260575985538972, 1.260370536352294, 1.300497519571223, 1.313207749734553, 1.336707999575244, 1.336707999575244, 1.339632503389684, 1.338396765486622, 1.329763215030373, 1.322203351805869, 1.292268467243897, 1.264393112372013, 1.242193341297951, 1.240971483263393, 1.240971483263393, 1.235334897177231, 1.224450695993367, 1.196006376647624, 1.161903954032878, 1.195538017201648, 1.23222140113546, 1.23222140113546, 1.23222140113546, 1.230071862411802, 1.230071862411802, 1.178633363356279, 1.192371805625888, 1.21890676792351, 1.25566441701967, 1.25566441701967, 1.254390239837099, 1.247889700134483, 1.233884818064123, 1.267600042268806, 1.267600042268806, 1.40564516756106, 1.40564516756106, 1.508877434028667, 1.811781381264022, 1.811781381264022, 1.624643812185306]
# lambda_var: [-0.842381470275944, -0.780183340247473, -0.752734126864824, -0.727265982537979, -0.713826547712261, -0.708828639427359, -0.706178892825776, -0.692195286111503, -0.684312068454232, -0.684312068454232, -0.687551283200988, -0.694115022641017, -0.744765112458638, -0.768596223129932, -0.770692059937109, -0.788699053822393, -0.793288156740857, -0.793417468242437, -0.768936491574165, -0.761494135411656, -0.748106542579055, -0.748106542579055, -0.746473377937375, -0.747162594670807, -0.752013583092806, -0.75631331491801, -0.773833011752398, -0.790893267461724, -0.805027660955833, -0.805820289576914, -0.805820289576914, -0.809497086405495, -0.816692744977146, -0.83611594346426, -0.8606563361189, -0.836443497079803, -0.811542470434717, -0.811542470434717, -0.811542470434717, -0.812960633079843, -0.812960633079843, -0.848440262332638, -0.8386645803614, -0.820407291448195, -0.796391126837462, -0.796391126837462, -0.797200080359255, -0.801352875892983, -0.810448418977169, -0.78889236877127, -0.78889236877127, -0.711417093785556, -0.711417093785556, -0.662744353814096, -0.551942971895612, -0.551942971895612, -0.615519532650607]
# pend_var: [array([-8.42381470e-05,  1.33951528e-01]), array([-7.80183340e-05,  3.97897652e-02]), array([-7.52734127e-05,  1.92678436e-03]), array([-7.27265983e-05, -2.99353339e-02]), array([-7.13826548e-05, -4.56801835e-02]), array([-7.08828639e-05, -5.12413185e-02]), array([-7.06178893e-05, -5.39036528e-02]), array([-6.92195286e-05, -6.70277130e-02]), array([-6.84312068e-05, -7.41358154e-02]), array([-6.84312068e-05, -7.41358154e-02]), array([-6.87551283e-05, -7.12868095e-02]), array([-6.94115023e-05, -6.56247286e-02]), array([-7.44765112e-05, -2.47450256e-02]), array([-7.68596223e-05, -7.62808499e-03]), array([-7.70692060e-05, -6.24832575e-03]), array([-7.88699054e-05,  5.15945377e-03]), array([-7.93288157e-05,  7.87830231e-03]), array([-7.93417468e-05,  7.96796430e-03]), array([-7.68936492e-05, -3.86780990e-03]), array([-7.61494135e-05, -7.34090945e-03]), array([-7.48106543e-05, -1.34112292e-02]), array([-7.48106543e-05, -1.34112292e-02]), array([-7.46473378e-05, -1.41325436e-02]), array([-7.47162595e-05, -1.38338830e-02]), array([-7.52013583e-05, -1.17858552e-02]), array([-7.56313315e-05, -1.00301313e-02]), array([-7.73833012e-05, -3.14410319e-03]), array([-7.90893267e-05,  3.14129487e-03]), array([-8.05027661e-05,  8.00981797e-03]), array([-8.05820290e-05,  8.41198236e-03]), array([-8.05820290e-05,  8.41198236e-03]), array([-8.09497086e-05,  9.48438143e-03]), array([-8.16692745e-05,  1.15231514e-02]), array([-8.36115943e-05,  1.67972818e-02]), array([-8.60656336e-05,  2.30083371e-02]), array([-8.36443497e-05,  1.80638633e-02]), array([-8.1154247e-05,  1.3083658e-02]), array([-8.1154247e-05,  1.3083658e-02]), array([-8.1154247e-05,  1.3083658e-02]), array([-8.12960633e-05,  1.33554725e-02]), array([-8.12960633e-05,  1.33554725e-02]), array([-8.48440262e-05,  1.97231597e-02]), array([-8.38664580e-05,  1.82965134e-02]), array([-8.20407291e-05,  1.57100642e-02]), array([-7.96391127e-05,  1.25079089e-02]), array([-7.96391127e-05,  1.25079089e-02]), array([-7.97200080e-05,  1.26090281e-02]), array([-8.01352876e-05,  1.30935209e-02]), array([-8.10448419e-05,  1.40788714e-02]), array([-7.88892369e-05,  1.22422374e-02]), array([-7.88892369e-05,  1.22422374e-02]), array([-7.11417094e-05,  6.52943524e-03]), array([-7.11417094e-05,  6.52943524e-03]), array([-6.62744354e-05,  3.28458591e-03]), array([-5.51942972e-05, -3.17882804e-03]), array([-5.51942972e-05, -3.17882804e-03]), array([-6.15519533e-05, -3.46944695e-18])]

# %%
N_cut = 16

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 2  # since Python indexes from zero, we need to subtract 1
tend = 49

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.0261071124125865, pinit: [ 1.02610711 -9.69933463]
# t[t0:tend]: [  500.   750.  1000.  1250.  1500.  1750.  2000.  2250.  2500.  2750.
#   3000.  3250.  3500.  3750.  4000.  4250.  4500.  4750.  5000.  5250.
#   5500.  5750.  6000.  6250.  6500.  6750.  7000.  7250.  7500.  7750.
#   8000.  8250.  8500.  8750.  9000.  9250.  9500.  9750. 10000. 10250.
#  10500. 10750. 11000. 11250. 11500. 11750. 12000.]
# n[t0:tend]: [-0.05129329 -0.05129329 -0.05129329 -0.06899287 -0.10536052 -0.12405265
#  -0.16251893 -0.16251893 -0.20252426 -0.20252426 -0.22314355 -0.24419696
#  -0.26570317 -0.31015493 -0.33314445 -0.35667494 -0.35667494 -0.3807725
#  -0.3807725  -0.3807725  -0.43078292 -0.51082562 -0.5389965  -0.5389965
#  -0.5389965  -0.5389965  -0.56798404 -0.56798404 -0.56798404 -0.597837
#  -0.597837   -0.62860866 -0.66035736 -0.72704873 -0.72704873 -0.72704873
#  -0.72704873 -0.76214005 -0.76214005 -0.76214005 -0.7985077  -0.7985077
#  -0.7985077  -0.83624802 -0.83624802 -0.83624802 -0.87546874]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 1.260575985538972, lambda: -7.93288156740857e-05

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 313 :</em></strong></p>

# %%
force = forces_data['force313']
force_value = 313
t, N = filter_data(force)

# %%
tau_frac = 2550
N_cut_max = 14 #+1

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [1.05662205205017, 1.15393969969257, 1.160885455507552, 1.140786194657328, 1.154425730052014, 1.164644174605124, 1.16635580961869, 1.17664316667049, 1.190041562070832, 1.220242311482064, 1.246598006724979, 1.285041935846092, 1.31997839565879, 1.325394426881698]
# lambda_var: [-0.946412199196197, -0.866596409038027, -0.861411429745916, -0.876588448110018, -0.866231559092974, -0.858631350076561, -0.857371302781888, -0.849875330368568, -0.840306785806595, -0.819509363501283, -0.802183217529095, -0.778184720751221, -0.757588156964424, -0.75449238333734]
# pend_var: [array([-9.46412199e-05, -5.93939533e-02]), array([-8.66596409e-05, -1.72416508e-01]), array([-8.61411430e-05, -1.79736996e-01]), array([-8.76588448e-05, -1.58908646e-01]), array([-8.66231559e-05, -1.59321483e-01]), array([-8.58631350e-05, -1.67243804e-01]), array([-8.57371303e-05, -1.68547953e-01]), array([-8.49875330e-05, -1.75642743e-01]), array([-8.40306786e-05, -1.84543603e-01]), array([-8.19509364e-05, -2.02829281e-01]), array([-8.02183218e-05, -2.17469106e-01]), array([-7.78184721e-05, -2.36947378e-01]), array([-7.57588157e-05, -2.53082740e-01]), array([-7.54492383e-05, -2.55466486e-01])]

# %%
N_cut = 4

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 19  # since Python indexes from zero, we need to subtract 1
tend = 91

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 0.7729926909385222, pinit: [ 0.77299269 -7.07487768]
# t[t0:tend]: [ 2850.  3000.  3150.  3300.  3450.  3600.  3750.  3900.  4050.  4200.
#   4350.  4500.  4650.  4800.  4950.  5100.  5250.  5400.  5550.  5700.
#   5850.  6000.  6150.  6300.  6450.  6600.  6750.  6900.  7050.  7200.
#   7350.  7500.  7650.  7800.  7950.  8100.  8250.  8400.  8550.  8700.
#   8850.  9000.  9150.  9300.  9450.  9600.  9750.  9900. 10050. 10200.
#  10350. 10500. 10650. 10800. 10950. 11100. 11250. 11400. 11550. 11700.
#  11850. 12000. 12150. 12300. 12450. 12600. 12750. 12900. 13050. 13200.
#  13350. 13500.]
# n[t0:tend]: [-0.35667494 -0.35667494 -0.39834764 -0.39834764 -0.41985385 -0.46430561
#  -0.51082562 -0.51082562 -0.53492318 -0.55961579 -0.55961579 -0.55961579
#  -0.55961579 -0.55961579 -0.61090908 -0.61090908 -0.63757733 -0.6649763
#  -0.6649763  -0.72213472 -0.72213472 -0.75198768 -0.75198768 -0.75198768
#  -0.75198768 -0.75198768 -0.81450804 -0.88119941 -0.88119941 -0.88119941
#  -0.88119941 -0.88119941 -0.88119941 -0.88119941 -0.91629073 -0.95265838
#  -0.95265838 -0.95265838 -0.95265838 -0.95265838 -0.95265838 -0.95265838
#  -0.9903987  -0.9903987  -1.02961942 -1.02961942 -1.02961942 -1.07044141
#  -1.07044141 -1.11300103 -1.11300103 -1.11300103 -1.11300103 -1.15745279
#  -1.15745279 -1.15745279 -1.15745279 -1.15745279 -1.15745279 -1.15745279
#  -1.15745279 -1.15745279 -1.15745279 -1.15745279 -1.15745279 -1.15745279
#  -1.15745279 -1.15745279 -1.15745279 -1.2039728  -1.2039728  -1.2039728 ]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 1.154425730052014, lambda: -8.662315590929741e-05

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 325 :</em></strong></p>

# %%
force = forces_data['force325']
force_value = 325

# %%
# Filtering
t, N = filter_data(force)

# %%
tau_frac = 0
N_cut_max = 81

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [0.613003399873429, 0.621492088964531, 0.617052480093352, 0.646776937509879, 0.725381048148684, 0.777149097900036, 0.787862875989904, 0.796672034483031, 0.803707354065683, 0.803707354065683, 0.810362599407906, 0.810362599407906, 0.810430538105219, 0.80750526538539, 0.80750526538539, 0.801993543547171, 0.794410290117806, 0.760816774464604, 0.754046189762034, 0.73152794857674, 0.722152680031941, 0.722152680031941, 0.719301348223551, 0.708972636004259, 0.6988864746032, 0.68797907899648, 0.683717448334966, 0.681030843777227, 0.677316092659723, 0.668571183169246, 0.659387403415567, 0.646591104907633, 0.6373739147527, 0.6373739147527, 0.626873207655262, 0.62399456986533, 0.618373401150129, 0.615781599030533, 0.611309639109363, 0.609664785265598, 0.607682294636527, 0.608840070336154, 0.612857463513335, 0.61785748393146, 0.636106635642264, 0.636106635642264, 0.636106635642264, 0.643068451900902, 0.643068451900902, 0.659376938827191, 0.659376938827191, 0.659376938827191, 0.664724972909204, 0.664724972909204, 0.664724972909204, 0.664724972909204, 0.659249831755416, 0.659249831755416, 0.660334470485559, 0.678373722125506, 0.701411702961371, 0.738219637062968, 0.738219637062968, 0.785760921863188, 0.785760921863188, 0.785760921863188, 0.785760921863188, 0.819266683787734, 0.819266683787734, 0.819266683787734, 0.819266683787734, 0.824697548988998, 0.838329124559387, 0.866271619687643, 0.866271619687643, 0.866271619687643, 0.866271619687643, 0.842060430785182, 0.842060430785182, 0.756567294318277, 0.719679997071382]
# lambda_var: [-1.631312322584958, -1.609030939824353, -1.620607699119388, -1.546128103840632, -1.378585782675461, -1.286754372747956, -1.269256402954078, -1.255221668034213, -1.244233980118932, -1.244233980118932, -1.234015489770448, -1.234015489770448, -1.233912041787064, -1.238382017884107, -1.238382017884107, -1.2468928310533, -1.258795376192453, -1.314376908558191, -1.326178705730992, -1.367001769304371, -1.384748720943291, -1.384748720943291, -1.390237905809139, -1.410491673749159, -1.430847550122874, -1.453532571744258, -1.462592482370117, -1.468362276301117, -1.476415533068384, -1.495727044739908, -1.516559149932333, -1.546572466602137, -1.56893775671381, -1.56893775671381, -1.59521891793776, -1.602578048420869, -1.617145883280351, -1.623952390870998, -1.635832213372151, -1.640245630333323, -1.645596735047432, -1.642467453641607, -1.631700777970931, -1.618496216371688, -1.5720634622689, -1.5720634622689, -1.5720634622689, -1.555044407860491, -1.555044407860491, -1.51658321836166, -1.51658321836166, -1.51658321836166, -1.504381572462137, -1.504381572462137, -1.504381572462137, -1.504381572462137, -1.516875624127581, -1.516875624127581, -1.514384065494381, -1.474113703677616, -1.425696200645048, -1.354610402912789, -1.354610402912789, -1.272651734358092, -1.272651734358092, -1.272651734358092, -1.272651734358092, -1.220603766500888, -1.220603766500888, -1.220603766500888, -1.220603766500888, -1.212565747559097, -1.192848930932209, -1.154372343815877, -1.154372343815877, -1.154372343815877, -1.154372343815877, -1.187563224016532, -1.187563224016532, -1.321759488560861, -1.38950645296428]
# pend_var: [array([-0.00016313,  0.12910602]), array([-0.0001609 ,  0.10900245]), array([-0.00016206,  0.12090247]), array([-0.00015461,  0.06979279]), array([-0.00013786, -0.03488149]), array([-0.00012868, -0.08852515]), array([-0.00012693, -0.098499  ]), array([-0.00012552, -0.10642862]), array([-0.00012442, -0.11258173]), array([-0.00012442, -0.11258173]), array([-0.0001234 , -0.11822518]), array([-0.0001234 , -0.11822518]), array([-0.00012339, -0.11828155]), array([-0.00012384, -0.11588106]), array([-0.00012384, -0.11588106]), array([-0.00012469, -0.11151807]), array([-0.00012588, -0.10553602]), array([-0.00013144, -0.07898844]), array([-0.00013262, -0.07370559]), array([-0.0001367 , -0.05625204]), array([-0.00013847, -0.04918454]), array([-0.00013847, -0.04918454]), array([-0.00013902, -0.0471261 ]), array([-0.00014105, -0.0397227 ]), array([-0.00014308, -0.03258591]), array([-0.00014535, -0.02500499]), array([-0.00014626, -0.02212387]), array([-0.00014684, -0.02033524]), array([-0.00014764, -0.017879  ]), array([-0.00014957, -0.01212969]), array([-0.00015166, -0.00613604]), array([-0.00015466,  0.00213852]), array([-0.00015689,  0.00798131]), array([-0.00015689,  0.00798131]), array([-0.00015952,  0.01445123]), array([-0.00016026,  0.01618063]), array([-0.00016171,  0.01950481]), array([-0.0001624 ,  0.02100224]), array([-0.00016358,  0.02353908]), array([-0.00016402,  0.02444383]), array([-0.00016456,  0.02551405]), array([-0.00016425,  0.02499537]), array([-0.00016317,  0.02305737]), array([-0.00016185,  0.02074657]), array([-0.00015721,  0.01300337]), array([-0.00015721,  0.01300337]), array([-0.00015721,  0.01300337]), array([-0.0001555 ,  0.01028032]), array([-0.0001555 ,  0.01028032]), array([-0.00015166,  0.00445237]), array([-0.00015166,  0.00445237]), array([-0.00015166,  0.00445237]), array([-0.00015044,  0.00268313]), array([-0.00015044,  0.00268313]), array([-0.00015044,  0.00268313]), array([-0.00015044,  0.00268313]), array([-0.00015169,  0.00449987]), array([-0.00015169,  0.00449987]), array([-0.00015144,  0.00418843]), array([-0.00014741, -0.00048318]), array([-0.00014257, -0.0058091 ]), array([-0.00013546, -0.01327311]), array([-0.00013546, -0.01327311]), array([-0.00012727, -0.02146898]), array([-0.00012727, -0.02146898]), array([-0.00012727, -0.02146898]), array([-0.00012727, -0.02146898]), array([-0.00012206, -0.02641354]), array([-0.00012206, -0.02641354]), array([-0.00012206, -0.02641354]), array([-0.00012206, -0.02641354]), array([-0.00012126, -0.02713696]), array([-0.00011928, -0.02881289]), array([-0.00011544, -0.03189102]), array([-0.00011544, -0.03189102]), array([-0.00011544, -0.03189102]), array([-0.00011544, -0.03189102]), array([-0.00011876, -0.0294017 ]), array([-0.00011876, -0.0294017 ]), array([-0.00013218, -0.0202963 ]), array([-0.00013895, -0.01623148])]

# %%
N_cut = 7

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 19  # since Python indexes from zero, we need to subtract 1
tend = 54

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 0.9400744554634617, pinit: [ 0.94007446 -8.25211268]
# t[t0:tend]: [2850. 3000. 3150. 3300. 3450. 3600. 3750. 3900. 4050. 4200. 4350. 4500.
#  4650. 4800. 4950. 5100. 5250. 5400. 5550. 5700. 5850. 6000. 6150. 6300.
#  6450. 6600. 6750. 6900. 7050. 7200. 7350. 7500. 7650. 7800. 7950.]
# n[t0:tend]: [-0.46203546 -0.49429632 -0.51082562 -0.52763274 -0.52763274 -0.54472718
#  -0.5798185  -0.5798185  -0.5798185  -0.65392647 -0.71334989 -0.71334989
#  -0.75502258 -0.82098055 -0.82098055 -0.84397007 -0.86750057 -0.89159812
#  -0.89159812 -0.89159812 -0.91629073 -0.94160854 -0.96758403 -0.96758403
#  -0.99425227 -1.02165125 -1.02165125 -1.04982212 -1.07880966 -1.07880966
#  -1.07880966 -1.13943428 -1.13943428 -1.13943428 -1.17118298]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 0.796672034483031, lambda: -0.0001255221668034213

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 338 :</em></strong></p>

# %%
force = forces_data['force338']
force_value = 338
t, N = filter_data(force)

# %%
tau_frac = 0
N_cut_max = 14 #+1

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [0.596312496144413, 0.480608712988577, 0.435022146092382, 0.430761480862053, 0.429958235504548, 0.428595146982202, 0.42891887530945, 0.42893252355889, 0.42893252355889, 0.424736335912175, 0.422441235003214, 0.423042649482971, 0.42318438884615, 0.423003069889788]
# lambda_var: [-1.676973074462998, -2.080694696069247, -2.298733544907018, -2.321470336666986, -2.325807293414254, -2.333204206909806, -2.331443211209895, -2.33136902677119, -2.33136902677119, -2.354401814604282, -2.36719315526192, -2.363827858070969, -2.363036128829304, -2.364049036950362]
# pend_var: [array([-1.67697307e-04, -6.70180429e-01]), array([-2.08069470e-04, -2.96392519e-01]), array([-0.00022987, -0.14500394]), array([-0.00023215, -0.1312394 ]), array([-0.00023258, -0.12902152]), array([-0.00023332, -0.12488735]), array([-0.00023314, -0.12566219]), array([-0.00023314, -0.12552248]), array([-0.00023314, -0.12552248]), array([-0.00023544, -0.11638492]), array([-0.00023672, -0.11144136]), array([-0.00023638, -0.11261922]), array([-0.0002363, -0.1128884]), array([-0.0002364 , -0.11255414])]

# %%
N_cut = 2

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 4  # since Python indexes from zero, we need to subtract 1
tend = 5

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: -0.06304128905497113, pinit: [-0.06304129 -0.44696758]
# t[t0:tend]: [1200.]
# n[t0:tend]: [-0.40904293]
# C:\Users\anast\Desktop\Ramd_calc\data_func.py:56: RankWarning: Polyfit may be poorly conditioned
#   pinit = np.polyfit(np.log(filtered_t), np.log(-filtered_n), 1)

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 0.435022146092382, lambda: -0.0002298733544907018

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 350 :</em></strong></p>

# %%
force = forces_data['force350']
force_value = 350
t, N = filter_data(force)

# %%
tau_frac = 1100
N_cut_max = 61 #+1

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [0.63602299552684, 0.629321948792017, 0.5417265948831, 0.544905313745813, 0.558402038501784, 0.563497085699034, 0.56319275569991, 0.561283804341215, 0.517209565735631, 0.535345399554324, 0.545289485866198, 0.549211977235315, 0.551636325673166, 0.554057656701425, 0.554048118770498, 0.554048118770498, 0.542308251449981, 0.526363180576117, 0.52246205321914, 0.492059143439102, 0.470206145316575, 0.46941882822368, 0.46941882822368, 0.465929121310406, 0.465929121310406, 0.452255954545304, 0.406553033406598, 0.387733159176479, 0.377852291805684, 0.377029479046083, 0.380115145970226, 0.380115145970226, 0.379834217448531, 0.378981906863517, 0.379166319784731, 0.387355405743232, 0.412212624798856, 0.412212624798856, 0.412212624798856, 0.421717478567051, 0.434596680640627, 0.434596680640627, 0.434596680640627, 0.434596680640627, 0.428651377362126, 0.419906210470958, 0.430171425522405, 0.449017445687204, 0.449017445687204, 0.449017445687204, 0.448570703003678, 0.450143945213943, 0.450143945213943, 0.435300584890075, 0.41666159582768, 0.41666159582768, 0.316512001221202, 0.300964485145622, 0.302607992325067, 0.409188058452678, 0.409188058452678]
# lambda_var: [-1.572270196255506, -1.589011795821676, -1.845949616366522, -1.835181222817878, -1.790824407953527, -1.774632070651212, -1.775591020799347, -1.781629885390531, -1.933452252720214, -1.867952915692377, -1.833888284883193, -1.820790589881, -1.812788522908986, -1.804866312927588, -1.804897383676935, -1.804897383676935, -1.84396972999448, -1.899828933523574, -1.914014604196648, -2.032276024810342, -2.126726777096312, -2.130293758740108, -2.130293758740108, -2.146249191695817, -2.146249191695817, -2.211137277353032, -2.459703698729731, -2.579093318002356, -2.646536812629056, -2.652312499622272, -2.630781779156804, -2.630781779156804, -2.632727527070422, -2.638648394262609, -2.637365050165169, -2.581608479378944, -2.425932491727931, -2.425932491727931, -2.425932491727931, -2.371255759656652, -2.300983980194988, -2.300983980194988, -2.300983980194988, -2.300983980194988, -2.332898137768483, -2.381484186381575, -2.324654639218746, -2.227084959849471, -2.227084959849471, -2.227084959849471, -2.229302968972095, -2.221511608969268, -2.221511608969268, -2.297263166445152, -2.400029208388027, -2.400029208388027, -3.159437860623575, -3.322651174327597, -3.304605381756673, -2.443864084845106, -2.443864084845106]
# pend_var: [array([-1.57227020e-04, -7.16035396e-01]), array([-1.58901180e-04, -6.99759853e-01]), array([-1.84594962e-04, -4.79370702e-01]), array([-1.83518122e-04, -4.85395407e-01]), array([-1.79082441e-04, -5.10902834e-01]), array([-1.77463207e-04, -5.19891362e-01]), array([-1.77559102e-04, -5.19367136e-01]), array([-1.78162989e-04, -5.16086020e-01]), array([-1.93345225e-04, -4.37984317e-01]), array([-1.86795292e-04, -4.63190358e-01]), array([-1.83388828e-04, -4.76868501e-01]), array([-1.82079059e-04, -4.82063920e-01]), array([-1.81278852e-04, -4.85211399e-01]), array([-1.80486631e-04, -4.88284684e-01]), array([-1.80489738e-04, -4.88272773e-01]), array([-1.80489738e-04, -4.88272773e-01]), array([-1.84396973e-04, -4.73603168e-01]), array([-1.89982893e-04, -4.53454908e-01]), array([-1.91401460e-04, -4.48489924e-01]), array([-2.03227602e-04, -4.08567352e-01]), array([-2.12672678e-04, -3.78770662e-01]), array([-2.13029376e-04, -3.77723049e-01]), array([-2.13029376e-04, -3.77723049e-01]), array([-2.14624919e-04, -3.73149158e-01]), array([-2.14624919e-04, -3.73149158e-01]), array([-2.21113728e-04, -3.54870120e-01]), array([-2.45970370e-04, -2.88389894e-01]), array([-2.57909332e-04, -2.58658421e-01]), array([-0.00026465, -0.24264289]), array([-0.00026523, -0.24110357]), array([-0.00026308, -0.24576856]), array([-0.00026308, -0.24576856]), array([-0.00026327, -0.24535346]), array([-0.00026386, -0.24411008]), array([-0.00026374, -0.24433669]), array([-0.00025816, -0.25534209]), array([-2.42593249e-04, -2.85098662e-01]), array([-2.42593249e-04, -2.85098662e-01]), array([-2.42593249e-04, -2.85098662e-01]), array([-2.37125576e-04, -2.95304985e-01]), array([-2.30098398e-04, -3.08188145e-01]), array([-2.30098398e-04, -3.08188145e-01]), array([-2.30098398e-04, -3.08188145e-01]), array([-2.30098398e-04, -3.08188145e-01]), array([-2.33289814e-04, -3.02443596e-01]), array([-2.38148419e-04, -2.93881598e-01]), array([-2.32465464e-04, -3.03337799e-01]), array([-2.22708496e-04, -3.19274180e-01]), array([-2.22708496e-04, -3.19274180e-01]), array([-2.22708496e-04, -3.19274180e-01]), array([-2.22930297e-04, -3.18919298e-01]), array([-2.22151161e-04, -3.20139945e-01]), array([-2.22151161e-04, -3.20139945e-01]), array([-2.29726317e-04, -3.08524706e-01]), array([-2.40002921e-04, -2.93109800e-01]), array([-2.40002921e-04, -2.93109800e-01]), array([-0.00031594, -0.18390233]), array([-0.00033227, -0.16159651]), array([-0.00033046, -0.16400261]), array([-2.44386408e-04, -2.75898980e-01]), array([-2.44386408e-04, -2.75898980e-01])]

# %%
N_cut = 10

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 1  # since Python indexes from zero, we need to subtract 1
tend = 12

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.5606709503847291, pinit: [  1.56067095 -11.36371341]
# t[t0:tend]: [ 100.  200.  300.  400.  500.  600.  700.  800.  900. 1000. 1100.]
# n[t0:tend]: [-0.00836825 -0.08701138 -0.11466291 -0.14310084 -0.18232156 -0.22314355
#  -0.31015493 -0.41804389 -0.4567584  -0.51082562 -0.55338524]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 0.545289485866198, lambda: -0.0001833888284883193

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 363 :</em></strong></p>

# %%
force = forces_data['force363']
force_value = 363
t, N = filter_data(force)

# %%
tau_frac = 1100
N_cut_max = 21 #+1

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [0.184170480299712, 0.188856271136457, 0.185105090807156, 0.19047341243453, 0.19047341243453, 0.193957032679306, 0.198882247866507, 0.202896923794309, 0.204445096820041, 0.204976810955123, 0.204911463235526, 0.204931994742939, 0.204613749614022, 0.203328926207924, 0.203069425180342, 0.218212475732662, 0.218212475732662, 0.225461007957574, 0.225461007957574, 0.242033606763769, 0.257588995653932]
# lambda_var: [-5.429751816754982, -5.295032004933824, -5.402336562649215, -5.250076570890046, -5.250076570890046, -5.155781082985662, -5.028100852275236, -4.928610948354117, -4.891288739882238, -4.878600634580744, -4.88015645493975, -4.879667527046588, -4.887257097269248, -4.91813938454286, -4.924424241177233, -4.582689402347127, -4.582689402347127, -4.435356734447729, -4.435356734447729, -4.131657637842113, -3.882153418321834]
# pend_var: [array([-0.00054298, -0.17785659]), array([-0.0005295 , -0.22565162]), array([-0.00054023, -0.18859976]), array([-0.00052501, -0.22825992]), array([-0.00052501, -0.22825992]), array([-0.00051558, -0.2531557 ]), array([-0.00050281, -0.28577395]), array([-0.00049286, -0.31043703]), array([-0.00048913, -0.31951877]), array([-0.00048786, -0.32256391]), array([-0.00048802, -0.32216083]), array([-0.00048797, -0.32223015]), array([-0.00048873, -0.32053515]), array([-0.00049181, -0.31374643]), array([-0.00049244, -0.31235863]), array([-0.00045827, -0.38023724]), array([-0.00045827, -0.38023724]), array([-0.00044354, -0.40872155]), array([-0.00044354, -0.40872155]), array([-4.13165764e-04, -4.65760366e-01]), array([-3.88215342e-04, -5.11502806e-01])]

# %%
N_cut = 7

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 2  # since Python indexes from zero, we need to subtract 1
tend = 12

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.177188599911417, pinit: [ 1.1771886 -8.3109412]
# t[t0:tend]: [ 200.  300.  400.  500.  600.  700.  800.  900. 1000. 1100.]
# n[t0:tend]: [-0.12136086 -0.20544397 -0.27820333 -0.36693144 -0.49899117 -0.55961579
#  -0.65118298 -0.76725515 -0.81450804 -0.86410498]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 0.202896923794309, lambda: -0.0004928610948354117

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 375 :</em></strong></p>

# %%
force = forces_data['force375']
force_value = 375
t, N = filter_data(force)

# %%
tau_frac = 630
N_cut_max = 61 #+1

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [0.144882733051436, 0.16469902617255, 0.16469902617255, 0.180151256559416, 0.180151256559416, 0.181093391722944, 0.180844391407868, 0.178260556532902, 0.175313156171018, 0.165984902670825, 0.160915437940241, 0.157917655431776, 0.152869544712381, 0.149094761337348, 0.148825080227426, 0.146875197258569, 0.146653069588605, 0.145660345906533, 0.143025694310277, 0.142645180467523, 0.141536305481475, 0.14231105281052, 0.144116224495642, 0.144116224495642, 0.144617305428767, 0.145276964529487, 0.145529141151991, 0.148122390684544, 0.149401753788095, 0.150518020767755, 0.150518020767755, 0.150518020767755, 0.152069216035559, 0.153635899532284, 0.153635899532284, 0.154025631458943, 0.154140726681885, 0.154581651376622, 0.15500397658, 0.15500397658, 0.153872933387772, 0.1522446956884, 0.150057679245855, 0.148718777804324, 0.148718777804324, 0.151147772437277, 0.151147772437277, 0.151147772437277, 0.149547613096699, 0.147404808273166, 0.144624069692602, 0.146477813954048, 0.15660791738054, 0.175296940671752, 0.175296940671752, 0.175296940671752, 0.175296940671752, 0.175296940671752, 0.174575123598764, 0.17344310182603, 0.171835996162805]
# lambda_var: [-6.902133739049354, -6.071681316150174, -6.071681316150174, -5.550891062867441, -5.550891062867441, -5.522012650411365, -5.529615777492645, -5.609765948505976, -5.704078472151294, -6.02464431348411, -6.214444137866804, -6.33241417665312, -6.54152533705432, -6.707143772391559, -6.719297570489194, -6.808501494228024, -6.818813972358212, -6.86528645649156, -6.991750711803037, -7.010401590312964, -7.065325017480297, -7.026861092310587, -6.938844002468597, -6.938844002468597, -6.914801773101503, -6.883403733267233, -6.871475995007754, -6.751173778511996, -6.693361855834407, -6.643722757575781, -6.643722757575781, -6.643722757575781, -6.575952885600246, -6.508895401688744, -6.508895401688744, -6.492425906830721, -6.487578082227382, -6.469073082701171, -6.451447389053834, -6.451447389053834, -6.498868761277993, -6.568373337923723, -6.664104129996562, -6.724100444906475, -6.724100444906475, -6.616041929529432, -6.616041929529432, -6.616041929529432, -6.686833572886187, -6.784039216324801, -6.914478358446818, -6.826972447265724, -6.385373209261907, -5.704606116729229, -5.704606116729229, -5.704606116729229, -5.704606116729229, -5.704606116729229, -5.728192994428915, -5.765579544368622, -5.81950244611469]
# pend_var: [array([-0.00069021, -0.18951466]), array([-0.00060717, -0.38988481]), array([-0.00060717, -0.38988481]), array([-0.00055509, -0.50425945]), array([-0.00055509, -0.50425945]), array([-0.0005522 , -0.51034891]), array([-0.00055296, -0.50876445]), array([-0.00056098, -0.49245906]), array([-0.00057041, -0.47386869]), array([-0.00060246, -0.41348671]), array([-0.00062144, -0.37997264]), array([-0.00063324, -0.36001477]), array([-0.00065415, -0.32593235]), array([-0.00067071, -0.30018705]), array([-0.00067193, -0.29838829]), array([-0.00068085, -0.28538976]), array([-0.00068188, -0.28394602]), array([-0.00068653, -0.27750677]), array([-0.00069918, -0.26038026]), array([-0.00070104, -0.257937  ]), array([-0.00070653, -0.25067924]), array([-0.00070269, -0.25538379]), array([-0.00069388, -0.26591227]), array([-0.00069388, -0.26591227]), array([-0.00069148, -0.26872915]), array([-0.00068834, -0.27234674]), array([-0.00068715, -0.2737065 ]), array([-0.00067512, -0.2870083 ]), array([-0.00066934, -0.2933098 ]), array([-0.00066437, -0.29867082]), array([-0.00066437, -0.29867082]), array([-0.00066437, -0.29867082]), array([-0.0006576 , -0.30552379]), array([-0.00065089, -0.31236365]), array([-0.00065089, -0.31236365]), array([-0.00064924, -0.31402707]), array([-0.00064876, -0.31451185]), array([-0.00064691, -0.31631695]), array([-0.00064514, -0.31802664]), array([-0.00064514, -0.31802664]), array([-0.00064989, -0.31347419]), array([-0.00065684, -0.30687126]), array([-0.00066641, -0.29787256]), array([-0.00067241, -0.29143003]), array([-0.00067241, -0.29143003]), array([-0.0006616 , -0.30083112]), array([-0.0006616 , -0.30083112]), array([-0.0006616 , -0.30083112]), array([-0.00066868, -0.29474304]), array([-0.0006784 , -0.28648056]), array([-0.00069145, -0.27552367]), array([-0.0006827 , -0.28189302]), array([-0.00063854, -0.31677936]), array([-0.00057046, -0.36987919]), array([-0.00057046, -0.36987919]), array([-0.00057046, -0.36987919]), array([-0.00057046, -0.36987919]), array([-0.00057046, -0.36987919]), array([-0.00057282, -0.368063  ]), array([-0.00057656, -0.36522163]), array([-0.00058195, -0.36117741])]

# %%
N_cut = 12

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 1  # since Python indexes from zero, we need to subtract 1
tend = 22

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.1298725319214458, pinit: [ 1.12987253 -7.64589616]
# t[t0:tend]: [ 30.  60.  90. 120. 150. 180. 210. 240. 270. 300. 330. 360. 390. 420.
#  450. 480. 510. 540. 570. 600. 630.]
# n[t0:tend]: [-0.02020271 -0.0618754  -0.06899287 -0.09065437 -0.15860503 -0.18232156
#  -0.20661425 -0.22314355 -0.2570451  -0.30110509 -0.32850407 -0.36624439
#  -0.40546511 -0.43592432 -0.46734051 -0.49977579 -0.556288   -0.60391605
#  -0.64118744 -0.65392647 -0.67990195]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 0.152869544712381, lambda: -0.000654152533705432

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 388 :</em></strong></p>

# %%
force = forces_data['force388']
force_value = 388
t, N = filter_data(force)

# %%
tau_frac = 630
N_cut_max = 61 #+1

# %%
N0 = N[0]
n = np.log(N / N0)
pend_var = []      # For linear fit coefficients
tau_var = []       # To store dissociation time values
lambda_var = []    # Dissociation rate values
calculate_dissociation_rates(t, n, N, N_cut_max, tau_frac, tau_var, lambda_var, pend_var)
print("tau_var:", tau_var)
print("lambda_var:", lambda_var)
print("pend_var:", pend_var)
# Out:
# tau_var: [0.108882156574053, 0.11138757289191, 0.122848353848683, 0.124447233479162, 0.130789959984348, 0.130789959984348, 0.130843806271408, 0.132368261798142, 0.133068259761435, 0.135837407390435, 0.135837407390435, 0.135790764846183, 0.135379199790849, 0.135036382661079, 0.135036382661079, 0.133055086029402, 0.133055086029402, 0.126998110538689, 0.124745915443303, 0.115570382490763, 0.113415708634209, 0.110755615595654, 0.103395518158513, 0.103395518158513, 0.105327767134851, 0.105327767134851, 0.105327767134851, 0.104971667817596, 0.105023478100365, 0.105023478100365, 0.10392951320635, 0.103301435587011, 0.103540715926895, 0.1053867238324, 0.110377740372791, 0.122369821538264, 0.122369821538264, 0.122369821538264, 0.122369821538264, 0.122369821538264, 0.127086853715331, 0.127086853715331, 0.127086853715331, 0.127086853715331, 0.121280619792455, 0.116503536179693, 0.116503536179693, 0.107248537804841, 0.107248537804841, 0.082945508812816, 0.082774520893308, 0.082774520893308, 0.082774520893308, 0.084901870157037, 0.084901870157037, 0.084901870157037, 0.154986558207235, 0.154986558207235, 0.154986558207235, 0.154986558207235, 0.154986558207235]
# lambda_var: [-9.184241306975583, -8.977662175747374, -8.140117215015685, -8.035534194236998, -7.645846822796461, -7.645846822796461, -7.642700319537536, -7.554681057344193, -7.514940090092119, -7.36174238901452, -7.36174238901452, -7.364271061678993, -7.386659114139619, -7.405411640134435, -7.405411640134435, -7.515684141371518, -7.515684141371518, -7.87413289660994, -8.016294533142434, -8.652735921159778, -8.817120767857858, -9.02888756133862, -9.671599096461089, -9.671599096461089, -9.49417259287097, -9.49417259287097, -9.49417259287097, -9.526380029872872, -9.521680466955718, -9.521680466955718, -9.621905935559655, -9.680407579212199, -9.65803636808974, -9.48886124964217, -9.059797714852571, -8.171949484189664, -8.171949484189664, -8.171949484189664, -8.171949484189664, -8.171949484189664, -7.868634487088293, -7.868634487088293, -7.868634487088293, -7.868634487088293, -8.245340448550499, -8.583430450193536, -8.583430450193536, -9.32413644482209, -9.32413644482209, -12.056107850959277, -12.081012239127862, -12.081012239127862, -12.081012239127862, -11.778303565638373, -11.778303565638373, -11.778303565638373, -6.452172443644322, -6.452172443644322, -6.452172443644322, -6.452172443644322, -6.452172443644322]
# pend_var: [array([-0.00091842, -0.47427415]), array([-0.00089777, -0.51599475]), array([-0.00081401, -0.66250489]), array([-0.00080355, -0.68045831]), array([-0.00076458, -0.74508026]), array([-0.00076458, -0.74508026]), array([-0.00076427, -0.74558895]), array([-7.55468106e-04, -7.58013484e-01]), array([-7.51494009e-04, -7.63842159e-01]), array([-7.36174239e-04, -7.85471164e-01]), array([-7.36174239e-04, -7.85471164e-01]), array([-7.36427106e-04, -7.85105422e-01]), array([-7.38665911e-04, -7.82083039e-01]), array([-7.40541164e-04, -7.79557996e-01]), array([-7.40541164e-04, -7.79557996e-01]), array([-7.51568414e-04, -7.65663449e-01]), array([-7.51568414e-04, -7.65663449e-01]), array([-0.00078741, -0.72199728]), array([-0.00080163, -0.70517482]), array([-0.00086527, -0.63233668]), array([-0.00088171, -0.61425435]), array([-0.00090289, -0.59131295]), array([-0.00096716, -0.52224113]), array([-0.00096716, -0.52224113]), array([-0.00094942, -0.53909665]), array([-0.00094942, -0.53909665]), array([-0.00094942, -0.53909665]), array([-0.00095264, -0.53609062]), array([-0.00095217, -0.53652141]), array([-0.00095217, -0.53652141]), array([-0.00096219, -0.52750112]), array([-0.00096804, -0.52233347]), array([-0.0009658 , -0.52427231]), array([-0.00094889, -0.5386522 ]), array([-0.00090598, -0.57440749]), array([-0.00081719, -0.6469151 ]), array([-0.00081719, -0.6469151 ]), array([-0.00081719, -0.6469151 ]), array([-0.00081719, -0.6469151 ]), array([-0.00081719, -0.6469151 ]), array([-0.00078686, -0.6711803 ]), array([-0.00078686, -0.6711803 ]), array([-0.00078686, -0.6711803 ]), array([-0.00078686, -0.6711803 ]), array([-0.00082453, -0.64167166]), array([-0.00085834, -0.61575143]), array([-0.00085834, -0.61575143]), array([-0.00093241, -0.56019848]), array([-0.00093241, -0.56019848]), array([-0.00120561, -0.36177424]), array([-0.0012081 , -0.36003093]), array([-0.0012081 , -0.36003093]), array([-0.0012081 , -0.36003093]), array([-0.00117783, -0.38071602]), array([-0.00117783, -0.38071602]), array([-0.00117783, -0.38071602]), array([-6.45217244e-04, -7.35791431e-01]), array([-6.45217244e-04, -7.35791431e-01]), array([-6.45217244e-04, -7.35791431e-01]), array([-6.45217244e-04, -7.35791431e-01]), array([-6.45217244e-04, -7.35791431e-01])]

# %%
N_cut = 9

# %%
a = np.arange(0, N_cut_max)
plot_tau_with_cutoff(a, tau_var, N_cut, tau_var, force_value)

# %%
t0 = 1  # since Python indexes from zero, we need to subtract 1
tend = 22

# %%
p, pinit = plot_init_part_ln_ln(force_value, n, t, t0, tend)
print(f"p: {p}, pinit: {pinit}")
print("t[t0:tend]:", t[t0:tend])
print("n[t0:tend]:", n[t0:tend])
# Out:
# p: 1.0834881378493182, pinit: [ 1.08348814 -6.94808015]
# t[t0:tend]: [  50.  100.  150.  200.  250.  300.  350.  400.  450.  500.  550.  600.
#   650.  700.  750.  800.  850.  900.  950. 1000. 1050.]
# n[t0:tend]: [-0.05129329 -0.13926207 -0.21072103 -0.33547274 -0.43850496 -0.51082562
#  -0.58878717 -0.68319685 -0.77652879 -0.90386821 -0.95451194 -1.04982212
#  -1.15518264 -1.1874435  -1.27296568 -1.32802545 -1.38629436 -1.40649707
#  -1.40649707 -1.44816976 -1.49165488]

# %%
tau = tau_var[N_cut]
lambda_ = lambda_var[N_cut] * 1e-4
print(f"tau: {tau}, lambda: {lambda_}")
# Out:
# tau: 0.135837407390435, lambda: -0.000736174238901452

# %%
t_fit = t[(N > N_cut) & (t > tau_frac)]
n_fit = n[(N > N_cut) & (t > tau_frac)]

plot_lnN(force_value, t, t_fit, n, tau_frac, pend_var[N_cut], pinit)
plot_N(force_value, t, t_fit, N, N0, tau_frac, pend_var[N_cut], pinit)

# %%
tau_all.append(tau)
forces_all.append(force_value)

# %% [markdown]
# <p style="color: darkblue; font-size: 24px;"><strong><em> force 400 :</em></strong></p>

# %%
tau_data = pd.DataFrame({
    "Force": forces_all,
    "Dissoc_Time_Tau": tau_all
})

print(tau_data)
tau_data.to_csv("tau_data.csv", index=False)
# Out:
#     Force  Dissoc_Time_Tau
# 0     250         1.486313
# 1     263         4.035113
# 2     275         2.643564
# 3     288         1.912803
# 4     300         1.260576
# 5     313         1.154426
# 6     325         0.796672
# 7     338         0.435022
# 8     350         0.545289
# 9     363         0.202897
# 10    375         0.152870
# 11    388         0.135837
